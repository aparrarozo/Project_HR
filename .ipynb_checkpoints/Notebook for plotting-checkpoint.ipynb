# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap
import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.ensemble import RandomForestClassifier

# %%
general= pd.read_csv('Data/general_hr_data.csv')
general
# Out:
#       Unnamed: 0  age attrition     businesstravel              department  \
# 0              0   51        No      Travel_Rarely                   Sales
# 1              1   31       Yes  Travel_Frequently  Research & Development
# 2              2   32        No  Travel_Frequently  Research & Development
# 3              3   38        No         Non-Travel  Research & Development
# 4              4   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4405   42        No      Travel_Rarely  Research & Development
# 4406        4406   29        No      Travel_Rarely  Research & Development
# 4407        4407   25        No      Travel_Rarely  Research & Development
# 4408        4408   42        No      Travel_Rarely                   Sales
# 4409        4409   40        No      Travel_Rarely  Research & Development
#
# ...

# %%
sns.boxplot(y='mean_time',x='jobrole', hue = 'attrition', data=general, palette ='colorblind')
# Out:
# <AxesSubplot:xlabel='jobrole', ylabel='mean_time'>

# %%
fig,ax = plt.subplots(figsize=(25,13))
sns.boxplot(y='mean_time',x='jobrole', hue = 'attrition', data=general)
plt.show()

# %%
filtered_age = general[general['age'] == 18]

# %%
filtered_age.age.value_counts()
# Out:
# 18    24
# Name: age, dtype: int64

# %%
filtered_age[filtered_age['attrition']=="Yes"]
# Out:
#       Unnamed: 0  age attrition     businesstravel              department  \
# 38            38   18       Yes      Travel_Rarely  Research & Development
# 199          199   18       Yes  Travel_Frequently  Research & Development
# 570          570   18       Yes         Non-Travel  Research & Development
# 895          895   18       Yes  Travel_Frequently  Research & Development
# 1508        1508   18       Yes      Travel_Rarely  Research & Development
# 1669        1669   18       Yes  Travel_Frequently  Research & Development
# 2040        2040   18       Yes         Non-Travel  Research & Development
# 2365        2365   18       Yes  Travel_Frequently  Research & Development
# 2978        2978   18       Yes      Travel_Rarely  Research & Development
# 3139        3139   18       Yes  Travel_Frequently  Research & Development
# 3510        3510   18       Yes         Non-Travel  Research & Development
# ...

# %%
features_20= pd.read_csv('Data/hr_feat_df.csv')
features_20
# Out:
#       Unnamed: 0  mean_time  totalworkingyears  age  jobsatisfaction  \
# 0              0   6.870229                  1   51                4
# 1              1   7.315971                  6   31                2
# 2              2   6.816081                  5   32                2
# 3              3   6.789215                 13   38                4
# 4              4   7.877561                  9   32                1
# ...          ...        ...                ...  ...              ...
# 7207        7207   6.152908                 13   35                3
# 7208        7208   8.155342                  3   30                2
# 7209        7209   8.679284                  8   35                3
# 7210        7210   7.436715                  3   26                2
# 7211        7211   7.809441                 13   35                4
#
#       yearswithcurrmanager  yearsatcompany  monthlyincome  \
# 0                        0               1         131160
# ...

# %%
features_20 = features_20.drop(['Unnamed: 0'], axis = 1).reset_index(drop = True)
features_20
# Out:
#       mean_time  totalworkingyears  age  jobsatisfaction  \
# 0      6.870229                  1   51                4
# 1      7.315971                  6   31                2
# 2      6.816081                  5   32                2
# 3      6.789215                 13   38                4
# 4      7.877561                  9   32                1
# ...         ...                ...  ...              ...
# 7207   6.152908                 13   35                3
# 7208   8.155342                  3   30                2
# 7209   8.679284                  8   35                3
# 7210   7.436715                  3   26                2
# 7211   7.809441                 13   35                4
#
#       yearswithcurrmanager  yearsatcompany  monthlyincome  \
# 0                        0               1         131160
# 1                        4               5          41890
# 2                        3               5         193280
# ...

# %%
filtered_age = features_20[features_20['age'] == 18] 
filtered_age
# Out:
#       mean_time  totalworkingyears  age  jobsatisfaction  \
# 35     6.177288                  0   18                3
# 40     6.755546                  0   18                3
# 189    8.933678                  0   18                2
# 452    5.958169                  0   18                4
# 545    6.572103                  0   18                3
# 685    7.731888                  0   18                4
# 862    8.195288                  0   18                4
# 1018   7.222269                  0   18                3
# 1463   6.350847                  0   18                3
# 1468   6.683172                  0   18                3
# 1617   9.029596                  0   18                2
# 1880   5.788685                  0   18                4
# 1977   6.401060                  0   18                3
# 2118   7.714944                  0   18                4
# 2296   7.709982                  0   18                4
# ...

# %%
filtered_age.age.value_counts()
# Out:
# 18    56
# Name: age, dtype: int64

# %%
filtered_age[filtered_age['attrition'] == 'Yes']
# Out:
# Empty DataFrame
# Columns: [mean_time, totalworkingyears, age, jobsatisfaction, yearswithcurrmanager, yearsatcompany, monthlyincome, maritalstatus_Married, maritalstatus_Divorced, distancefromhome, trainingtimeslastyear, percentsalaryhike, worklifebalance, yearssincelastpromotion, numcompaniesworked, education, gender_Female, joblevel, stockoptionlevel, attrition]
# Index: []

# %%
fig,ax = plt.subplots(figsize=(25,13))
sns.boxplot(y='mean_time',x='maritalstatus', hue= 'attrition',data=general)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(25,13))
sns.boxplot(y='mean_time',x='attrition',data=general)
plt.show()

# %%
corr= features_20.corr()

# %%
corr
# Out:
#                          mean_time  totalworkingyears       age  \
# mean_time                 1.000000          -0.096663 -0.043907
# totalworkingyears        -0.096663           1.000000  0.693184
# age                      -0.043907           0.693184  1.000000
# jobsatisfaction          -0.013196           0.053195  0.064248
# yearswithcurrmanager     -0.098291           0.510695  0.273874
# yearsatcompany           -0.113047           0.684930  0.390060
# monthlyincome            -0.032784          -0.005345 -0.039736
# maritalstatus_Married    -0.107856           0.149188  0.164876
# maritalstatus_Divorced   -0.042616           0.079334  0.075407
# distancefromhome         -0.022052           0.011688  0.015002
# trainingtimeslastyear    -0.038848          -0.061417 -0.066113
# percentsalaryhike         0.008904          -0.043152 -0.018417
# worklifebalance          -0.068374           0.031495  0.009645
# yearssincelastpromotion  -0.049125           0.452945  0.267666
# ...

# %%
import statsmodels.api as sm
from scipy.stats import boxcox
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax =plt.subplots(figsize=(20, 20))
    multicollinearity_ax = sns.heatmap(corr, mask=mask, cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
fig,ax = plt.subplots(figsize=(25,13))
sns.boxplot(y='monthlyincome',x='attrition',data=general)
plt.show()

# %%
hr_up= pd.read_csv('Data/hr_up_df.csv')
hr_up
# Out:
#       Unnamed: 0  department_Human Resources  \
# 0              0                           0
# 1              1                           0
# 2              2                           0
# 3              3                           0
# 4              4                           0
# ...          ...                         ...
# 7207        7207                           0
# 7208        7208                           0
# 7209        7209                           0
# 7210        7210                           0
# 7211        7211                           0
#
#       department_Research & Development  department_Sales  \
# 0                                     0                 1
# 1                                     1                 0
# 2                                     1                 0
# 3                                     1                 0
# 4                                     1                 0
# ...                                 ...               ...
# ...

# %%
sns.set(rc={'figure.figsize':(11,8)}, font_scale=1.5, style='whitegrid')
plot= sns.boxplot(y='attrition',x='totalworkingyears', data=hr_up)
